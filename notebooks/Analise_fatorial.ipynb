# %% [markdown]
# # Análise Fatorial Exploratória

# %% [markdown]
# ### Import libs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from ipywidgets import interact
import numpy as np

#Stats and ml libs
from factor_analyzer import calculate_bartlett_sphericity, calculate_kmo, FactorAnalyzer

# Settings
from sklearn import set_config
set_config(transform_output = 'pandas')

# %% [markdown]
# ### Read Data

# %% [markdown]
# Estou utilizando a base de dados World Energy Consumption que encontrei no [Kaggle](https://www.kaggle.com/datasets/pralabhpoudel/world-energy-consumption)
#
# * Após alguns testes, fiz a seleção de 55 colunas de forma que atenda os pressupostos
#
# **Pressupostos da Análise Fatorial**
# * Variáveis correlacionadas;
# * Uso apenas de variáveis quantitativas contínuas;
# * Existência de mais observações que variáveis;
# * Dados sem outliers.

# %%
# Read csv file
df = pd.read_csv('../Data/World Energy Consumption.csv')

#Drop columns 
df.drop("other_renewable_exc_biofuel_electricity", axis = 1, inplace= True)

# Select data
df = df.iloc[:,list(np.arange(36,91))].copy()
df.head()
# Out:
#    other_renewable_electricity  renewables_electricity  solar_electricity  \
# 0                          NaN                     NaN                NaN
# 1                          NaN                     NaN                NaN
# 2                          NaN                     NaN                NaN
# 3                          NaN                     NaN                NaN
# 4                          NaN                     NaN                NaN
#
#    wind_electricity  energy_per_gdp  energy_per_capita  \
# 0               NaN             NaN                NaN
# 1               NaN             NaN                NaN
# 2               NaN             NaN                NaN
# 3               NaN             NaN                NaN
# 4               NaN             NaN                NaN
#
#    fossil_cons_change_pct  fossil_share_energy  fossil_cons_change_twh  \
# 0                     NaN                  NaN                     NaN
# 1                     NaN                  NaN                     NaN
# 2                     NaN                  NaN                     NaN
# 3                     NaN                  NaN                     NaN
# 4                     NaN                  NaN                     NaN
#
#    fossil_fuel_consumption  ...  oil_cons_change_pct  oil_share_energy  \
# 0                      NaN  ...                  NaN               NaN
# 1                      NaN  ...                  NaN               NaN
# 2                      NaN  ...                  NaN               NaN
# 3                      NaN  ...                  NaN               NaN
# 4                      NaN  ...                  NaN               NaN
#
#    oil_cons_change_twh  oil_consumption  oil_elec_per_capita  \
# 0                  NaN              NaN                  NaN
# 1                  NaN              NaN                  NaN
# 2                  NaN              NaN                  NaN
# 3                  NaN              NaN                  NaN
# 4                  NaN              NaN                  NaN
#
#    oil_energy_per_capita  oil_production  oil_prod_per_capita  \
# 0                    NaN             NaN                  NaN
# 1                    NaN             NaN                  NaN
# 2                    NaN             NaN                  NaN
# 3                    NaN             NaN                  NaN
# 4                    NaN             NaN                  NaN
#
#    other_renewables_elec_per_capita  other_renewables_share_elec
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
# [5 rows x 55 columns]

# %% [markdown]
# **Como o objetivo principal desse estudo é explorar a análise fatorial exploratórial (AFE), não me aterei a efetuar um tratamento de dados minucioso, utilizando de alternativas simples e pouco indicadas no uso real.**

# %%
df.shape
# Out:
# (17432, 55)

# %%
df.describe().T
# Out:
#                                    count          mean            std  \
# other_renewable_electricity       6084.0      5.158606      30.998008
# renewables_electricity            6084.0     64.331314     340.491017
# solar_electricity                 6119.0      1.701370      21.100053
# wind_electricity                  6119.0      5.217070      48.966752
# energy_per_gdp                    6900.0      1.838233       1.570968
# energy_per_capita                 9035.0  29602.526450   75226.270234
# fossil_cons_change_pct            4201.0      3.371886      11.958375
# fossil_share_energy               4284.0     87.055670      14.866718
# fossil_cons_change_twh            4201.0     48.272569     309.766281
# fossil_fuel_consumption           4284.0   2737.591594   11071.914988
# fossil_energy_per_capita          4284.0  32913.395612   34982.870747
# fossil_cons_per_capita            4759.0   2419.259758    3110.985643
# fossil_share_elec                 5056.0     75.697896      68.257752
# gas_share_elec                    5056.0     23.625540      38.024176
# gas_cons_change_pct               3704.0     22.388298     370.699566
# gas_share_energy                  4284.0     20.811585      20.448799
# gas_cons_change_twh               4207.0     17.541433     101.047260
# gas_consumption                   5170.0    665.597784    2606.562650
# gas_elec_per_capita               4759.0    907.396716    2373.982795
# gas_energy_per_capita             4290.0  10255.938063   22836.841035
# gas_production                    8066.0    457.555107    2144.712240
# gas_prod_per_capita               7340.0  11183.484270   48617.001337
# hydro_share_elec                  6076.0     26.510166      31.112530
# hydro_cons_change_pct             3664.0      6.050609      42.551808
# hydro_share_energy                4284.0      8.624511      12.279163
# hydro_cons_change_twh             4207.0      3.925384      32.757877
# hydro_consumption                 4290.0    195.804979     807.979259
# hydro_elec_per_capita             5499.0    990.131814    3371.343049
# hydro_energy_per_capita           4290.0   3606.955152   10738.671434
# low_carbon_share_elec             6041.0     35.235897      32.896845
# low_carbon_electricity            6084.0    106.400388     542.289829
# low_carbon_elec_per_capita        5499.0   1571.514678    4240.002319
# low_carbon_cons_change_pct        3835.0     12.326407     146.666981
# low_carbon_share_energy           4284.0     12.895019      14.833220
# low_carbon_cons_change_twh        4207.0     12.932609      68.783596
# low_carbon_consumption            4290.0    399.489127    1691.769097
# low_carbon_energy_per_capita      4290.0   5636.071590   13121.876092
# nuclear_share_elec                6076.0      5.148774      13.218829
# nuclear_cons_change_pct           1522.0     40.757106     410.927441
# nuclear_share_energy              4284.0      3.126016       6.639930
# nuclear_cons_change_twh           4207.0      4.253995      34.640366
# nuclear_consumption               4290.0    160.179614     699.043693
# nuclear_elec_per_capita           5499.0    398.263166    1121.930999
# nuclear_energy_per_capita         4290.0   1480.345145    3398.947417
# oil_share_elec                    5056.0     34.456027      40.390115
# oil_cons_change_pct               4201.0      2.991044       9.944001
# oil_share_energy                  4284.0     48.480120      20.782870
# oil_cons_change_twh               4201.0     18.209294     142.752842
# oil_consumption                   5184.0   1238.016348    4534.636834
# oil_elec_per_capita               4759.0    883.318706    1850.269499
# oil_energy_per_capita             4284.0  16714.337677   17316.746066
# oil_production                    8710.0    875.005559    3622.276271
# oil_prod_per_capita               7924.0  46181.325954  229626.713218
# other_renewables_elec_per_capita  5499.0    114.717355     781.526379
# other_renewables_share_elec       6041.0      1.980329       4.726515
#
#                                        min          25%         50%  \
# other_renewable_electricity          0.000      0.00000      0.0110
# renewables_electricity               0.000      0.08375      2.7855
# solar_electricity                    0.000      0.00000      0.0000
# wind_electricity                     0.000      0.00000      0.0000
# energy_per_gdp                       0.050      0.84175      1.3945
# energy_per_capita                    0.000   3102.61450  13776.7170
# fossil_cons_change_pct             -52.574     -0.86600      2.6270
# fossil_share_energy                 17.162     81.79225     92.1655
# fossil_cons_change_twh           -2147.294     -1.48700      5.4020
# fossil_fuel_consumption              0.855    121.40500    296.3295
# fossil_energy_per_capita           124.142  11247.63475  25509.7340
# fossil_cons_per_capita               0.000    199.25600   1323.2910
# fossil_share_elec                    0.000     43.51250     77.1835
# gas_share_elec                       0.000      0.00000      8.1760
# gas_cons_change_pct                -95.245     -0.56850      4.1640
# gas_share_energy                     0.000      3.83975     15.8380
# gas_cons_change_twh               -613.301      0.00000      1.3720
# gas_consumption                      0.000      7.86325     51.6880
# gas_elec_per_capita                  0.000      0.00000     62.3250
# gas_energy_per_capita                0.000    443.83875   4082.8765
# gas_production                       0.000      0.00000      0.2145
# gas_prod_per_capita                  0.000      0.00000      0.0000
# hydro_share_elec                     0.000      0.22175     12.5195
# hydro_cons_change_pct              -80.585     -6.17450      2.4130
# hydro_share_energy                   0.000      0.52175      4.0840
# hydro_cons_change_twh             -266.952     -0.46950      0.0060
# hydro_consumption                    0.000      1.37650     13.5840
# hydro_elec_per_capita                0.000      1.62150    116.7870
# hydro_energy_per_capita              0.000     85.19000    576.7430
# low_carbon_share_elec                0.000      3.66300     27.7210
# low_carbon_electricity               0.000      0.08375      3.7200
# low_carbon_elec_per_capita           0.000     16.80150    234.3160
# low_carbon_cons_change_pct         -92.152     -1.98150      3.8800
# low_carbon_share_energy              0.000      2.02000      7.8250
# low_carbon_cons_change_twh        -383.227     -0.12800      0.3660
# low_carbon_consumption               0.000      3.25875     30.5075
# low_carbon_energy_per_capita         0.000    198.20025   1185.6885
# nuclear_share_elec                   0.000      0.00000      0.0000
# nuclear_cons_change_pct           -100.000     -2.18800      2.6045
# nuclear_share_energy                 0.000      0.00000      0.0000
# nuclear_cons_change_twh           -510.129      0.00000      0.0000
# nuclear_consumption                  0.000      0.00000      0.0000
# nuclear_elec_per_capita              0.000      0.00000      0.0000
# nuclear_energy_per_capita            0.000      0.00000      0.0000
# oil_share_elec                       0.000      1.59475     12.4780
# oil_cons_change_pct                -73.921     -1.64900      2.4060
# oil_share_energy                     5.053     34.16675     45.0795
# oil_cons_change_twh              -1446.860     -2.02600      2.6630
# oil_consumption                      0.000     67.63900    154.2265
# oil_elec_per_capita                  0.000     16.10700    148.9360
# oil_energy_per_capita              124.142   5316.35300  12149.0385
# oil_production                       0.000      0.00000      5.8730
# oil_prod_per_capita                  0.000      0.00000    158.6400
# other_renewables_elec_per_capita     0.000      0.00000      0.3860
# other_renewables_share_elec          0.000      0.00000      0.0700
#
#                                           75%          max
# other_renewable_electricity           0.67000      702.888
# renewables_electricity               17.42575     7492.505
# solar_electricity                     0.00900      844.386
# wind_electricity                      0.04700     1590.189
# energy_per_gdp                        2.34500       13.493
# energy_per_capita                 36713.59500  1676609.704
# fossil_cons_change_pct                6.41200      492.819
# fossil_share_energy                  97.95125      100.000
# fossil_cons_change_twh               27.43100     5477.970
# fossil_fuel_consumption            1068.12325   136761.607
# fossil_energy_per_capita          40568.66900   317582.498
# fossil_cons_per_capita             3592.21400    20640.919
# fossil_share_elec                    98.13325      806.124
# gas_share_elec                       33.80275      310.457
# gas_cons_change_pct                  11.08525    15300.000
# gas_share_energy                     30.49875       90.744
# gas_cons_change_twh                  10.00600     2195.737
# gas_consumption                     259.31125    39292.468
# gas_elec_per_capita                 767.67900    20611.253
# gas_energy_per_capita             10359.87625   278892.439
# gas_production                      104.63725    39893.382
# gas_prod_per_capita                2240.45350   740193.351
# hydro_share_elec                     48.55425      100.000
# hydro_cons_change_pct                12.06375     1750.000
# hydro_share_energy                   10.85425       71.055
# hydro_cons_change_twh                 2.35050      477.238
# hydro_consumption                    73.78475    10455.127
# hydro_elec_per_capita               658.68450    41592.814
# hydro_energy_per_capita            2124.32325   105642.710
# low_carbon_share_elec                61.12500      100.000
# low_carbon_electricity               23.89375    10109.117
# low_carbon_elec_per_capita         1419.33000    57655.786
# low_carbon_cons_change_pct           12.26900     8345.716
# low_carbon_share_energy              18.13825       82.835
# low_carbon_cons_change_twh            5.38150     1174.696
# low_carbon_consumption              130.90425    25427.562
# low_carbon_energy_per_capita       5047.52700   146224.492
# nuclear_share_elec                    0.00000       86.920
# nuclear_cons_change_pct              13.56375    11200.000
# nuclear_share_energy                  2.12175       41.707
# nuclear_cons_change_twh               0.00000      650.982
# nuclear_consumption                  29.72200     7493.281
# nuclear_elec_per_capita               0.00000     8899.826
# nuclear_energy_per_capita           637.71300    24721.759
# oil_share_elec                       68.14000      267.855
# oil_cons_change_pct                   6.83800      142.590
# oil_share_energy                     62.36550      100.000
# oil_cons_change_twh                  12.98500     2368.173
# oil_consumption                     512.24375    53619.925
# oil_elec_per_capita                 653.03200    11933.939
# oil_energy_per_capita             22638.96875   151237.334
# oil_production                      238.75500    52244.640
# oil_prod_per_capita                7854.82725  3758745.665
# other_renewables_elec_per_capita     42.50100    17495.575
# other_renewables_share_elec           1.54400       49.047

# %%
# Replacing NaN values
df = df.replace(np.nan, 0)

# %% [markdown]
# * Efetuei a padronização dos dados, porem em um uso real é indicado tratar os outliers para garantir que os resultados são confiáveis

# %%
# Preprocessing data
preprocessing = StandardScaler()
df_scaled = pd.DataFrame(preprocessing.fit_transform(df.select_dtypes(float)), columns=df.select_dtypes(float).columns)
df_scaled.head()
# Out:
#    other_renewable_electricity  renewables_electricity  solar_electricity  \
# 0                    -0.097448               -0.110353          -0.047676
# 1                    -0.097448               -0.110353          -0.047676
# 2                    -0.097448               -0.110353          -0.047676
# 3                    -0.097448               -0.110353          -0.047676
# 4                    -0.097448               -0.110353          -0.047676
#
#    wind_electricity  energy_per_gdp  energy_per_capita  \
# 0         -0.062898       -0.544633          -0.273307
# 1         -0.062898       -0.544633          -0.273307
# 2         -0.062898       -0.544633          -0.273307
# 3         -0.062898       -0.544633          -0.273307
# 4         -0.062898       -0.544633          -0.273307
#
#    fossil_cons_change_pct  fossil_share_energy  fossil_cons_change_twh  \
# 0                -0.13444            -0.560091               -0.075815
# 1                -0.13444            -0.560091               -0.075815
# 2                -0.13444            -0.560091               -0.075815
# 3                -0.13444            -0.560091               -0.075815
# 4                -0.13444            -0.560091               -0.075815
#
#    fossil_fuel_consumption  ...  oil_cons_change_pct  oil_share_energy  \
# 0                -0.119855  ...            -0.142854         -0.511865
# 1                -0.119855  ...            -0.142854         -0.511865
# 2                -0.119855  ...            -0.142854         -0.511865
# 3                -0.119855  ...            -0.142854         -0.511865
# 4                -0.119855  ...            -0.142854         -0.511865
#
#    oil_cons_change_twh  oil_consumption  oil_elec_per_capita  \
# 0            -0.062244        -0.145144            -0.231054
# 1            -0.062244        -0.145144            -0.231054
# 2            -0.062244        -0.145144            -0.231054
# 3            -0.062244        -0.145144            -0.231054
# 4            -0.062244        -0.145144            -0.231054
#
#    oil_energy_per_capita  oil_production  oil_prod_per_capita  \
# 0              -0.366722       -0.168322            -0.134132
# 1              -0.366722       -0.168322            -0.134132
# 2              -0.366722       -0.168322            -0.134132
# 3              -0.366722       -0.168322            -0.134132
# 4              -0.366722       -0.168322            -0.134132
#
#    other_renewables_elec_per_capita  other_renewables_share_elec
# 0                         -0.081849                     -0.23363
# 1                         -0.081849                     -0.23363
# 2                         -0.081849                     -0.23363
# 3                         -0.081849                     -0.23363
# 4                         -0.081849                     -0.23363
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Pressuposto 1: Correlação entre variáveis

# %% [markdown]
# Um dos pressupostos é a correlação entre as variáveis. No entanto, gerar o tradicional plot de mapa de calor com as correlações lineares, à medida que aumenta a quantidade de variáveis do dataset utilizado, pode torná-lo praticamente inútil para análises e visualizações eficazes.

# %%
df_scaled.corr()
# Out:
#                                   other_renewable_electricity  \
# other_renewable_electricity                          1.000000
# renewables_electricity                               0.958534
# solar_electricity                                    0.749237
# wind_electricity                                     0.872707
# energy_per_gdp                                       0.010132
# energy_per_capita                                    0.032040
# fossil_cons_change_pct                              -0.000408
# fossil_share_energy                                  0.119755
# fossil_cons_change_twh                               0.396199
# fossil_fuel_consumption                              0.755364
# fossil_energy_per_capita                             0.085109
# fossil_cons_per_capita                               0.126859
# fossil_share_elec                                    0.072204
# gas_share_elec                                       0.050644
# gas_cons_change_pct                                 -0.001106
# gas_share_energy                                     0.092487
# gas_cons_change_twh                                  0.537064
# gas_consumption                                      0.803875
# gas_elec_per_capita                                  0.060847
# gas_energy_per_capita                                0.040905
# gas_production                                       0.760963
# gas_prod_per_capita                                  0.005397
# hydro_share_elec                                     0.041760
# hydro_cons_change_pct                               -0.000576
# hydro_share_energy                                   0.051411
# hydro_cons_change_twh                                0.317410
# hydro_consumption                                    0.766239
# hydro_elec_per_capita                                0.032823
# hydro_energy_per_capita                              0.027436
# low_carbon_share_elec                                0.104560
# low_carbon_electricity                               0.942847
# low_carbon_elec_per_capita                           0.072590
# low_carbon_cons_change_pct                          -0.000334
# low_carbon_share_energy                              0.114704
# low_carbon_cons_change_twh                           0.607541
# low_carbon_consumption                               0.832262
# low_carbon_energy_per_capita                         0.066173
# nuclear_share_elec                                   0.141782
# nuclear_cons_change_pct                             -0.000954
# nuclear_share_energy                                 0.125156
# nuclear_cons_change_twh                              0.079010
# nuclear_consumption                                  0.764825
# nuclear_elec_per_capita                              0.125256
# nuclear_energy_per_capita                            0.117299
# oil_share_elec                                      -0.014891
# oil_cons_change_pct                                 -0.002051
# oil_share_energy                                     0.080663
# oil_cons_change_twh                                  0.263413
# oil_consumption                                      0.743377
# oil_elec_per_capita                                  0.000920
# oil_energy_per_capita                                0.077049
# oil_production                                       0.616673
# oil_prod_per_capita                                 -0.008462
# other_renewables_elec_per_capita                     0.036186
# other_renewables_share_elec                          0.086371
#
#                                   renewables_electricity  solar_electricity  \
# other_renewable_electricity                     0.958534           0.749237
# renewables_electricity                          1.000000           0.708376
# solar_electricity                               0.708376           1.000000
# wind_electricity                                0.819729           0.937650
# energy_per_gdp                                  0.024020          -0.014829
# energy_per_capita                               0.028369           0.007804
# fossil_cons_change_pct                          0.004953          -0.003633
# fossil_share_energy                             0.118452           0.045875
# fossil_cons_change_twh                          0.451821           0.150890
# fossil_fuel_consumption                         0.791100           0.359926
# fossil_energy_per_capita                        0.074811           0.025919
# fossil_cons_per_capita                          0.101649           0.054717
# fossil_share_elec                               0.081362           0.038652
# gas_share_elec                                  0.055602           0.029367
# gas_cons_change_pct                            -0.001237          -0.000775
# gas_share_energy                                0.089097           0.037869
# gas_cons_change_twh                             0.571474           0.299867
# gas_consumption                                 0.835101           0.412689
# gas_elec_per_capita                             0.045941           0.033609
# gas_energy_per_capita                           0.037452           0.013653
# gas_production                                  0.803546           0.386727
# gas_prod_per_capita                             0.012255          -0.000028
# hydro_share_elec                                0.082039           0.011385
# hydro_cons_change_pct                           0.001844          -0.001095
# hydro_share_energy                              0.082623           0.013056
# hydro_cons_change_twh                           0.372756           0.130852
# hydro_consumption                               0.819049           0.375220
# hydro_elec_per_capita                           0.062663           0.007730
# hydro_energy_per_capita                         0.053256           0.003584
# low_carbon_share_elec                           0.132374           0.046647
# low_carbon_electricity                          0.980305           0.620861
# low_carbon_elec_per_capita                      0.087295           0.027430
# low_carbon_cons_change_pct                     -0.000079           0.000365
# low_carbon_share_energy                         0.128056           0.044290
# low_carbon_cons_change_twh                      0.653429           0.417339
# low_carbon_consumption                          0.855647           0.427049
# low_carbon_energy_per_capita                    0.078866           0.019667
# nuclear_share_elec                              0.141021           0.056336
# nuclear_cons_change_pct                         0.002008          -0.000151
# nuclear_share_energy                            0.116307           0.042533
# nuclear_cons_change_twh                         0.171627           0.059329
# nuclear_consumption                             0.788668           0.312581
# nuclear_elec_per_capita                         0.111477           0.042594
# nuclear_energy_per_capita                       0.104284           0.032324
# oil_share_elec                                 -0.015231          -0.010804
# oil_cons_change_pct                             0.004599          -0.001063
# oil_share_energy                                0.074325           0.024944
# oil_cons_change_twh                             0.307406           0.128237
# oil_consumption                                 0.789805           0.356360
# oil_elec_per_capita                            -0.005584          -0.003475
# oil_energy_per_capita                           0.064873           0.019971
# oil_production                                  0.672132           0.283695
# oil_prod_per_capita                            -0.006824          -0.004815
# other_renewables_elec_per_capita                0.018614           0.012768
# other_renewables_share_elec                     0.052539           0.037844
#
#                                   wind_electricity  energy_per_gdp  \
# other_renewable_electricity               0.872707        0.010132
# renewables_electricity                    0.819729        0.024020
# solar_electricity                         0.937650       -0.014829
# wind_electricity                          1.000000       -0.008621
# energy_per_gdp                           -0.008621        1.000000
# energy_per_capita                         0.017340        0.223427
# fossil_cons_change_pct                   -0.003911        0.089149
# fossil_share_energy                       0.073116        0.509893
# fossil_cons_change_twh                    0.225956        0.060217
# fossil_fuel_consumption                   0.515641        0.076479
# fossil_energy_per_capita                  0.047992        0.461121
# fossil_cons_per_capita                    0.082102        0.158359
# fossil_share_elec                         0.048340        0.058858
# gas_share_elec                            0.036677        0.087820
# gas_cons_change_pct                      -0.000911        0.019217
# gas_share_energy                          0.059346        0.419053
# gas_cons_change_twh                       0.403849        0.051359
# gas_consumption                           0.566345        0.058214
# gas_elec_per_capita                       0.049371        0.147570
# gas_energy_per_capita                     0.025866        0.324645
# gas_production                            0.533345        0.051386
# gas_prod_per_capita                       0.003850        0.187950
# hydro_share_elec                          0.017959        0.113968
# hydro_cons_change_pct                     0.000104        0.055835
# hydro_share_energy                        0.025246        0.252236
# hydro_cons_change_twh                     0.213584        0.051476
# hydro_consumption                         0.529504        0.073102
# hydro_elec_per_capita                     0.016534        0.154385
# hydro_energy_per_capita                   0.011123        0.205688
# low_carbon_share_elec                     0.065754        0.154604
# low_carbon_electricity                    0.750120        0.029354
# low_carbon_elec_per_capita                0.046508        0.174181
# low_carbon_cons_change_pct                0.000296        0.028755
# low_carbon_share_energy                   0.072674        0.277632
# low_carbon_cons_change_twh                0.518279        0.052554
# low_carbon_consumption                    0.596403        0.057548
# low_carbon_energy_per_capita              0.038370        0.225664
# nuclear_share_elec                        0.087513        0.176110
# nuclear_cons_change_pct                  -0.001281        0.018044
# nuclear_share_energy                      0.074138        0.185457
# nuclear_cons_change_twh                   0.019853        0.048250
# nuclear_consumption                       0.476428        0.051556
# nuclear_elec_per_capita                   0.076684        0.153792
# nuclear_energy_per_capita                 0.064695        0.180418
# oil_share_elec                           -0.015170       -0.039700
# oil_cons_change_pct                      -0.000839        0.094635
# oil_share_energy                          0.042874        0.402573
# oil_cons_change_twh                       0.171008        0.048984
# oil_consumption                           0.491168        0.057713
# oil_elec_per_capita                      -0.005259       -0.005086
# oil_energy_per_capita                     0.039655        0.402184
# oil_production                            0.401065        0.040642
# oil_prod_per_capita                      -0.005516        0.025420
# other_renewables_elec_per_capita          0.017378        0.077666
# other_renewables_share_elec               0.046666        0.026435
#
#                                   energy_per_capita  fossil_cons_change_pct  \
# other_renewable_electricity                0.032040               -0.000408
# renewables_electricity                     0.028369                0.004953
# solar_electricity                          0.007804               -0.003633
# wind_electricity                           0.017340               -0.003911
# energy_per_gdp                             0.223427                0.089149
# energy_per_capita                          1.000000                0.049665
# fossil_cons_change_pct                     0.049665                1.000000
# fossil_share_energy                        0.224126                0.253978
# fossil_cons_change_twh                     0.017222                0.104624
# fossil_fuel_consumption                    0.051676                0.021313
# fossil_energy_per_capita                   0.392790                0.159165
# fossil_cons_per_capita                     0.348584                0.028848
# fossil_share_elec                          0.123643                0.011936
# gas_share_elec                             0.101081                0.038470
# gas_cons_change_pct                        0.009580                0.038377
# gas_share_energy                           0.229008                0.198066
# gas_cons_change_twh                        0.033114                0.076651
# gas_consumption                            0.052693                0.008998
# gas_elec_per_capita                        0.245976                0.047312
# gas_energy_per_capita                      0.319938                0.156426
# gas_production                             0.047867                0.007491
# gas_prod_per_capita                        0.241667                0.066560
# hydro_share_elec                           0.013441               -0.005094
# hydro_cons_change_pct                      0.011162                0.012447
# hydro_share_energy                         0.140530                0.081022
# hydro_cons_change_twh                      0.010934                0.008952
# hydro_consumption                          0.050157                0.019461
# hydro_elec_per_capita                      0.154594               -0.001786
# hydro_energy_per_capita                    0.179655                0.014205
# low_carbon_share_elec                      0.054718               -0.018809
# low_carbon_electricity                     0.038485                0.002912
# low_carbon_elec_per_capita                 0.178874               -0.010977
# low_carbon_cons_change_pct                 0.019029                0.007830
# low_carbon_share_energy                    0.174168                0.047658
# low_carbon_cons_change_twh                 0.033081                0.010995
# low_carbon_consumption                     0.054551                0.009753
# low_carbon_energy_per_capita               0.204605                0.001853
# nuclear_share_elec                         0.108392               -0.030639
# nuclear_cons_change_pct                    0.010246                0.011085
# nuclear_share_energy                       0.123457               -0.033033
# nuclear_cons_change_twh                    0.029997                0.013167
# nuclear_consumption                        0.060359                0.001311
# nuclear_elec_per_capita                    0.132074               -0.026627
# nuclear_energy_per_capita                  0.146663               -0.029143
# oil_share_elec                             0.122158               -0.017485
# oil_cons_change_pct                        0.051044                0.563169
# oil_share_energy                           0.174460                0.251510
# oil_cons_change_twh                        0.015614                0.099082
# oil_consumption                            0.047489                0.017602
# oil_elec_per_capita                        0.247204               -0.006287
# oil_energy_per_capita                      0.352226                0.137403
# oil_production                             0.027943                0.022506
# oil_prod_per_capita                        0.110873                0.170497
# other_renewables_elec_per_capita           0.110495               -0.003274
# other_renewables_share_elec                0.046803               -0.010150
#
#                                   fossil_share_energy  fossil_cons_change_twh  \
# other_renewable_electricity                  0.119755                0.396199
# renewables_electricity                       0.118452                0.451821
# solar_electricity                            0.045875                0.150890
# wind_electricity                             0.073116                0.225956
# energy_per_gdp                               0.509893                0.060217
# energy_per_capita                            0.224126                0.017222
# fossil_cons_change_pct                       0.253978                0.104624
# fossil_share_energy                          1.000000                0.138260
# fossil_cons_change_twh                       0.138260                1.000000
# fossil_fuel_consumption                      0.208564                0.645720
# fossil_energy_per_capita                     0.646832                0.059744
# fossil_cons_per_capita                       0.316476                0.038268
# fossil_share_elec                            0.148220                0.038730
# gas_share_elec                               0.213292                0.016515
# gas_cons_change_pct                          0.048669                0.004934
# gas_share_energy                             0.691985                0.066506
# gas_cons_change_twh                          0.150052                0.818907
# gas_consumption                              0.181531                0.562793
# gas_elec_per_capita                          0.258648                0.012606
# gas_energy_per_capita                        0.389788                0.023920
# gas_production                               0.157056                0.525303
# gas_prod_per_capita                          0.160542                0.004844
# hydro_share_elec                             0.053429                0.005898
# hydro_cons_change_pct                        0.114868                0.007046
# hydro_share_energy                           0.368637                0.040999
# hydro_cons_change_twh                        0.098085                0.428336
# hydro_consumption                            0.189715                0.620681
# hydro_elec_per_capita                        0.077275                0.001551
# hydro_energy_per_capita                      0.138323                0.008536
# low_carbon_share_elec                        0.155109                0.017413
# low_carbon_electricity                       0.136501                0.469106
# low_carbon_elec_per_capita                   0.138542                0.004285
# low_carbon_cons_change_pct                   0.074508                0.004558
# low_carbon_share_energy                      0.437337                0.047429
# low_carbon_cons_change_twh                   0.152550                0.532164
# low_carbon_consumption                       0.184999                0.559763
# low_carbon_energy_per_capita                 0.197972                0.010600
# nuclear_share_elec                           0.271418                0.038106
# nuclear_cons_change_pct                      0.051675                0.009540
# nuclear_share_energy                         0.289175                0.034666
# nuclear_cons_change_twh                      0.103341                0.314754
# nuclear_consumption                          0.179860                0.496962
# nuclear_elec_per_capita                      0.233093                0.014488
# nuclear_energy_per_capita                    0.261534                0.015537
# oil_share_elec                              -0.060627               -0.011799
# oil_cons_change_pct                          0.269153                0.116868
# oil_share_energy                             0.899178                0.093614
# oil_cons_change_twh                          0.114229                0.826412
# oil_consumption                              0.192484                0.610885
# oil_elec_per_capita                          0.019703               -0.002687
# oil_energy_per_capita                        0.636703                0.055695
# oil_production                               0.144906                0.560700
# oil_prod_per_capita                          0.120542               -0.001277
# other_renewables_elec_per_capita             0.048847               -0.002006
# other_renewables_share_elec                  0.087233                0.001083
#
#                                   fossil_fuel_consumption  ...  \
# other_renewable_electricity                      0.755364  ...
# renewables_electricity                           0.791100  ...
# solar_electricity                                0.359926  ...
# wind_electricity                                 0.515641  ...
# energy_per_gdp                                   0.076479  ...
# energy_per_capita                                0.051676  ...
# fossil_cons_change_pct                           0.021313  ...
# fossil_share_energy                              0.208564  ...
# fossil_cons_change_twh                           0.645720  ...
# fossil_fuel_consumption                          1.000000  ...
# fossil_energy_per_capita                         0.141716  ...
# fossil_cons_per_capita                           0.127354  ...
# fossil_share_elec                                0.064149  ...
# gas_share_elec                                   0.041423  ...
# gas_cons_change_pct                              0.000382  ...
# gas_share_energy                                 0.142848  ...
# gas_cons_change_twh                              0.719873  ...
# gas_consumption                                  0.946358  ...
# gas_elec_per_capita                              0.058264  ...
# gas_energy_per_capita                            0.068946  ...
# gas_production                                   0.899175  ...
# gas_prod_per_capita                              0.016888  ...
# hydro_share_elec                                 0.012807  ...
# hydro_cons_change_pct                            0.008684  ...
# hydro_share_energy                               0.064290  ...
# hydro_cons_change_twh                            0.514557  ...
# hydro_consumption                                0.981187  ...
# hydro_elec_per_capita                            0.018684  ...
# hydro_energy_per_capita                          0.029133  ...
# low_carbon_share_elec                            0.061394  ...
# low_carbon_electricity                           0.835161  ...
# low_carbon_elec_per_capita                       0.048679  ...
# low_carbon_cons_change_pct                       0.004842  ...
# low_carbon_share_energy                          0.116498  ...
# low_carbon_cons_change_twh                       0.784701  ...
# low_carbon_consumption                           0.966191  ...
# low_carbon_energy_per_capita                     0.061958  ...
# nuclear_share_elec                               0.135615  ...
# nuclear_cons_change_pct                          0.006606  ...
# nuclear_share_energy                             0.138051  ...
# nuclear_cons_change_twh                          0.389840  ...
# nuclear_consumption                              0.906021  ...
# nuclear_elec_per_capita                          0.110439  ...
# nuclear_energy_per_capita                        0.122580  ...
# oil_share_elec                                  -0.021898  ...
# oil_cons_change_pct                              0.022675  ...
# oil_share_energy                                 0.141680  ...
# oil_cons_change_twh                              0.470265  ...
# oil_consumption                                  0.953575  ...
# oil_elec_per_capita                             -0.001197  ...
# oil_energy_per_capita                            0.127998  ...
# oil_production                                   0.841026  ...
# oil_prod_per_capita                             -0.005338  ...
# other_renewables_elec_per_capita                 0.010246  ...
# other_renewables_share_elec                      0.021617  ...
#
#                                   oil_cons_change_pct  oil_share_energy  \
# other_renewable_electricity                 -0.002051          0.080663
# renewables_electricity                       0.004599          0.074325
# solar_electricity                           -0.001063          0.024944
# wind_electricity                            -0.000839          0.042874
# energy_per_gdp                               0.094635          0.402573
# energy_per_capita                            0.051044          0.174460
# fossil_cons_change_pct                       0.563169          0.251510
# fossil_share_energy                          0.269153          0.899178
# fossil_cons_change_twh                       0.116868          0.093614
# fossil_fuel_consumption                      0.022675          0.141680
# fossil_energy_per_capita                     0.165754          0.506341
# fossil_cons_per_capita                       0.026611          0.213562
# fossil_share_elec                            0.001919          0.081125
# gas_share_elec                               0.025260          0.141640
# gas_cons_change_pct                          0.018981          0.053701
# gas_share_energy                             0.129185          0.451419
# gas_cons_change_twh                          0.051944          0.106175
# gas_consumption                              0.004517          0.118843
# gas_elec_per_capita                          0.049672          0.184183
# gas_energy_per_capita                        0.134289          0.215660
# gas_production                               0.002553          0.096189
# gas_prod_per_capita                          0.076216          0.059977
# hydro_share_elec                            -0.009395          0.069318
# hydro_cons_change_pct                        0.030243          0.101694
# hydro_share_energy                           0.089599          0.425770
# hydro_cons_change_twh                        0.017508          0.064310
# hydro_consumption                            0.020127          0.136238
# hydro_elec_per_capita                       -0.004000          0.087284
# hydro_energy_per_capita                      0.011912          0.163785
# low_carbon_share_elec                       -0.020910          0.146883
# low_carbon_electricity                       0.001361          0.089283
# low_carbon_elec_per_capita                  -0.012586          0.136141
# low_carbon_cons_change_pct                   0.017232          0.071125
# low_carbon_share_energy                      0.053423          0.460509
# low_carbon_cons_change_twh                   0.015087          0.104548
# low_carbon_consumption                       0.008240          0.131193
# low_carbon_energy_per_capita                -0.001247          0.208764
# nuclear_share_elec                          -0.031031          0.204643
# nuclear_cons_change_pct                      0.027034          0.046277
# nuclear_share_energy                        -0.038676          0.238233
# nuclear_cons_change_twh                      0.012347          0.080722
# nuclear_consumption                         -0.003786          0.127805
# nuclear_elec_per_capita                     -0.029868          0.194828
# nuclear_energy_per_capita                   -0.037257          0.226365
# oil_share_elec                              -0.025165         -0.048575
# oil_cons_change_pct                          1.000000          0.286058
# oil_share_energy                             0.286058          1.000000
# oil_cons_change_twh                          0.164275          0.090907
# oil_consumption                              0.018364          0.140675
# oil_elec_per_capita                         -0.011835          0.018759
# oil_energy_per_capita                        0.161459          0.635955
# oil_production                               0.022097          0.103818
# oil_prod_per_capita                          0.132804          0.082598
# other_renewables_elec_per_capita            -0.000909          0.054558
# other_renewables_share_elec                 -0.006543          0.092875
#
#                                   oil_cons_change_twh  oil_consumption  \
# other_renewable_electricity                  0.263413         0.743377
# renewables_electricity                       0.307406         0.789805
# solar_electricity                            0.128237         0.356360
# wind_electricity                             0.171008         0.491168
# energy_per_gdp                               0.048984         0.057713
# energy_per_capita                            0.015614         0.047489
# fossil_cons_change_pct                       0.099082         0.017602
# fossil_share_energy                          0.114229         0.192484
# fossil_cons_change_twh                       0.826412         0.610885
# fossil_fuel_consumption                      0.470265         0.953575
# fossil_energy_per_capita                     0.053346         0.137901
# fossil_cons_per_capita                       0.024214         0.115953
# fossil_share_elec                            0.020446         0.073817
# gas_share_elec                               0.006777         0.052661
# gas_cons_change_pct                          0.003842         0.000022
# gas_share_energy                             0.047225         0.130674
# gas_cons_change_twh                          0.611083         0.684942
# gas_consumption                              0.400251         0.958666
# gas_elec_per_capita                          0.006638         0.053081
# gas_energy_per_capita                        0.018210         0.063904
# gas_production                               0.355977         0.906843
# gas_prod_per_capita                          0.002322         0.012020
# hydro_share_elec                             0.000953         0.017378
# hydro_cons_change_pct                        0.004219         0.005722
# hydro_share_energy                           0.035551         0.060410
# hydro_cons_change_twh                        0.283709         0.476153
# hydro_consumption                            0.446826         0.931929
# hydro_elec_per_capita                        0.000101         0.015382
# hydro_energy_per_capita                      0.007251         0.028447
# low_carbon_share_elec                        0.009138         0.068163
# low_carbon_electricity                       0.315815         0.831783
# low_carbon_elec_per_capita                   0.001784         0.045734
# low_carbon_cons_change_pct                   0.004718         0.004155
# low_carbon_share_energy                      0.035934         0.112131
# low_carbon_cons_change_twh                   0.369878         0.734079
# low_carbon_consumption                       0.384725         0.915068
# low_carbon_energy_per_capita                 0.006770         0.061772
# nuclear_share_elec                           0.026011         0.144225
# nuclear_cons_change_pct                      0.013204         0.006727
# nuclear_share_energy                         0.017044         0.137317
# nuclear_cons_change_twh                      0.247075         0.408818
# nuclear_consumption                          0.314178         0.869781
# nuclear_elec_per_capita                      0.008436         0.111136
# nuclear_energy_per_capita                    0.004229         0.125394
# oil_share_elec                              -0.009993        -0.019690
# oil_cons_change_pct                          0.164275         0.018364
# oil_share_energy                             0.090907         0.140675
# oil_cons_change_twh                          1.000000         0.461058
# oil_consumption                              0.461058         1.000000
# oil_elec_per_capita                         -0.001506        -0.004622
# oil_energy_per_capita                        0.057947         0.132711
# oil_production                               0.423240         0.861373
# oil_prod_per_capita                         -0.000146        -0.007986
# other_renewables_elec_per_capita            -0.002148         0.008932
# other_renewables_share_elec                 -0.001164         0.023754
#
#                                   oil_elec_per_capita  oil_energy_per_capita  \
# other_renewable_electricity                  0.000920               0.077049
# renewables_electricity                      -0.005584               0.064873
# solar_electricity                           -0.003475               0.019971
# wind_electricity                            -0.005259               0.039655
# energy_per_gdp                              -0.005086               0.402184
# energy_per_capita                            0.247204               0.352226
# fossil_cons_change_pct                      -0.006287               0.137403
# fossil_share_energy                          0.019703               0.636703
# fossil_cons_change_twh                      -0.002687               0.055695
# fossil_fuel_consumption                     -0.001197               0.127998
# fossil_energy_per_capita                     0.049424               0.872403
# fossil_cons_per_capita                       0.561250               0.445286
# fossil_share_elec                            0.314447               0.114841
# gas_share_elec                               0.005651               0.226432
# gas_cons_change_pct                         -0.004821               0.035515
# gas_share_energy                             0.014223               0.462576
# gas_cons_change_twh                          0.001329               0.084058
# gas_consumption                             -0.003650               0.128498
# gas_elec_per_capita                          0.028855               0.455284
# gas_energy_per_capita                        0.015639               0.520755
# gas_production                              -0.008292               0.111280
# gas_prod_per_capita                         -0.006644               0.251017
# hydro_share_elec                            -0.040730               0.024706
# hydro_cons_change_pct                       -0.005692               0.039697
# hydro_share_energy                          -0.042314               0.288287
# hydro_cons_change_twh                       -0.010411               0.029033
# hydro_consumption                           -0.006189               0.115369
# hydro_elec_per_capita                       -0.003935               0.198306
# hydro_energy_per_capita                     -0.021591               0.284781
# low_carbon_share_elec                       -0.024163               0.116303
# low_carbon_electricity                      -0.002116               0.087785
# low_carbon_elec_per_capita                   0.007121               0.259281
# low_carbon_cons_change_pct                   0.041814               0.066483
# low_carbon_share_energy                     -0.030271               0.361104
# low_carbon_cons_change_twh                  -0.008541               0.081950
# low_carbon_consumption                      -0.001795               0.124577
# low_carbon_energy_per_capita                -0.014273               0.342475
# nuclear_share_elec                          -0.001508               0.231095
# nuclear_cons_change_pct                     -0.005294               0.033122
# nuclear_share_energy                        -0.001507               0.268205
# nuclear_cons_change_twh                     -0.004058               0.079755
# nuclear_consumption                          0.003760               0.137760
# nuclear_elec_per_capita                      0.007828               0.272266
# nuclear_energy_per_capita                    0.003980               0.313162
# oil_share_elec                               0.600428              -0.038142
# oil_cons_change_pct                         -0.011835               0.161459
# oil_share_energy                             0.018759               0.635955
# oil_cons_change_twh                         -0.001506               0.057947
# oil_consumption                             -0.004622               0.132711
# oil_elec_per_capita                          1.000000               0.063455
# oil_energy_per_capita                        0.063455               1.000000
# oil_production                              -0.007941               0.094949
# oil_prod_per_capita                         -0.017782               0.227047
# other_renewables_elec_per_capita             0.012027               0.138870
# other_renewables_share_elec                  0.033911               0.099648
#
#                                   oil_production  oil_prod_per_capita  \
# other_renewable_electricity             0.616673            -0.008462
# renewables_electricity                  0.672132            -0.006824
# solar_electricity                       0.283695            -0.004815
# wind_electricity                        0.401065            -0.005516
# energy_per_gdp                          0.040642             0.025420
# energy_per_capita                       0.027943             0.110873
# fossil_cons_change_pct                  0.022506             0.170497
# fossil_share_energy                     0.144906             0.120542
# fossil_cons_change_twh                  0.560700            -0.001277
# fossil_fuel_consumption                 0.841026            -0.005338
# fossil_energy_per_capita                0.101384             0.282920
# fossil_cons_per_capita                  0.079565             0.082658
# fossil_share_elec                       0.063577            -0.007081
# gas_share_elec                          0.077912             0.054361
# gas_cons_change_pct                    -0.001829             0.003617
# gas_share_energy                        0.125461             0.232491
# gas_cons_change_twh                     0.624211             0.002843
# gas_consumption                         0.864117            -0.004251
# gas_elec_per_capita                     0.059532             0.147573
# gas_energy_per_capita                   0.065696             0.322305
# gas_production                          0.896826             0.000065
# gas_prod_per_capita                     0.028861             0.257515
# hydro_share_elec                        0.008412            -0.027152
# hydro_cons_change_pct                   0.003191            -0.004500
# hydro_share_energy                      0.044814             0.007635
# hydro_cons_change_twh                   0.435779            -0.004369
# hydro_consumption                       0.830595            -0.004108
# hydro_elec_per_capita                   0.017338             0.032750
# hydro_energy_per_capita                 0.024990             0.034388
# low_carbon_share_elec                   0.032954            -0.036935
# low_carbon_electricity                  0.700105            -0.007769
# low_carbon_elec_per_capita              0.026038             0.018266
# low_carbon_cons_change_pct              0.005156             0.006136
# low_carbon_share_energy                 0.065891            -0.006538
# low_carbon_cons_change_twh              0.643177            -0.006669
# low_carbon_consumption                  0.796777            -0.006063
# low_carbon_energy_per_capita            0.035724             0.020562
# nuclear_share_elec                      0.077738            -0.024819
# nuclear_cons_change_pct                 0.001643            -0.003398
# nuclear_share_energy                    0.065969            -0.024228
# nuclear_cons_change_twh                 0.343582            -0.003831
# nuclear_consumption                     0.735503            -0.007723
# nuclear_elec_per_capita                 0.044686            -0.019296
# nuclear_energy_per_capita               0.051458            -0.019897
# oil_share_elec                         -0.015438            -0.039387
# oil_cons_change_pct                     0.022097             0.132804
# oil_share_energy                        0.103818             0.082598
# oil_cons_change_twh                     0.423240            -0.000146
# oil_consumption                         0.861373            -0.007986
# oil_elec_per_capita                    -0.007941            -0.017782
# oil_energy_per_capita                   0.094949             0.227047
# oil_production                          1.000000             0.028713
# oil_prod_per_capita                     0.028713             1.000000
# other_renewables_elec_per_capita       -0.002172            -0.009057
# other_renewables_share_elec            -0.002113            -0.028261
#
#                                   other_renewables_elec_per_capita  \
# other_renewable_electricity                               0.036186
# renewables_electricity                                    0.018614
# solar_electricity                                         0.012768
# wind_electricity                                          0.017378
# energy_per_gdp                                            0.077666
# energy_per_capita                                         0.110495
# fossil_cons_change_pct                                   -0.003274
# fossil_share_energy                                       0.048847
# fossil_cons_change_twh                                   -0.002006
# fossil_fuel_consumption                                   0.010246
# fossil_energy_per_capita                                  0.091494
# fossil_cons_per_capita                                    0.045101
# fossil_share_elec                                         0.003831
# gas_share_elec                                            0.004543
# gas_cons_change_pct                                      -0.001574
# gas_share_energy                                          0.020241
# gas_cons_change_twh                                       0.003712
# gas_consumption                                           0.010267
# gas_elec_per_capita                                       0.022036
# gas_energy_per_capita                                     0.014081
# gas_production                                            0.006142
# gas_prod_per_capita                                      -0.003246
# hydro_share_elec                                          0.135008
# hydro_cons_change_pct                                     0.004271
# hydro_share_energy                                        0.308449
# hydro_cons_change_twh                                    -0.001092
# hydro_consumption                                         0.014728
# hydro_elec_per_capita                                     0.631689
# hydro_energy_per_capita                                   0.574537
# low_carbon_share_elec                                     0.195603
# low_carbon_electricity                                    0.020147
# low_carbon_elec_per_capita                                0.706742
# low_carbon_cons_change_pct                                0.001154
# low_carbon_share_energy                                   0.362240
# low_carbon_cons_change_twh                                0.006699
# low_carbon_consumption                                    0.019624
# low_carbon_energy_per_capita                              0.654931
# nuclear_share_elec                                        0.068001
# nuclear_cons_change_pct                                  -0.001982
# nuclear_share_energy                                      0.077582
# nuclear_cons_change_twh                                  -0.003877
# nuclear_consumption                                       0.020061
# nuclear_elec_per_capita                                   0.107203
# nuclear_energy_per_capita                                 0.097893
# oil_share_elec                                           -0.007784
# oil_cons_change_pct                                      -0.000909
# oil_share_energy                                          0.054558
# oil_cons_change_twh                                      -0.002148
# oil_consumption                                           0.008932
# oil_elec_per_capita                                       0.012027
# oil_energy_per_capita                                     0.138870
# oil_production                                           -0.002172
# oil_prod_per_capita                                      -0.009057
# other_renewables_elec_per_capita                          1.000000
# other_renewables_share_elec                               0.411456
#
#                                   other_renewables_share_elec
# other_renewable_electricity                          0.086371
# renewables_electricity                               0.052539
# solar_electricity                                    0.037844
# wind_electricity                                     0.046666
# energy_per_gdp                                       0.026435
# energy_per_capita                                    0.046803
# fossil_cons_change_pct                              -0.010150
# fossil_share_energy                                  0.087233
# fossil_cons_change_twh                               0.001083
# fossil_fuel_consumption                              0.021617
# fossil_energy_per_capita                             0.068525
# fossil_cons_per_capita                               0.074448
# fossil_share_elec                                    0.074168
# gas_share_elec                                       0.032088
# gas_cons_change_pct                                  0.001398
# gas_share_energy                                     0.049127
# gas_cons_change_twh                                  0.008233
# gas_consumption                                      0.023066
# gas_elec_per_capita                                  0.032463
# gas_energy_per_capita                                0.013167
# gas_production                                       0.012483
# gas_prod_per_capita                                 -0.021060
# hydro_share_elec                                     0.259229
# hydro_cons_change_pct                               -0.000455
# hydro_share_energy                                   0.170641
# hydro_cons_change_twh                                0.000636
# hydro_consumption                                    0.027961
# hydro_elec_per_capita                                0.253455
# hydro_energy_per_capita                              0.211276
# low_carbon_share_elec                                0.403278
# low_carbon_electricity                               0.048265
# low_carbon_elec_per_capita                           0.316682
# low_carbon_cons_change_pct                          -0.001385
# low_carbon_share_energy                              0.244610
# low_carbon_cons_change_twh                           0.016295
# low_carbon_consumption                               0.036200
# low_carbon_energy_per_capita                         0.267052
# nuclear_share_elec                                   0.087549
# nuclear_cons_change_pct                             -0.003830
# nuclear_share_energy                                 0.088483
# nuclear_cons_change_twh                             -0.012025
# nuclear_consumption                                  0.032748
# nuclear_elec_per_capita                              0.116465
# nuclear_energy_per_capita                            0.101379
# oil_share_elec                                       0.076885
# oil_cons_change_pct                                 -0.006543
# oil_share_energy                                     0.092875
# oil_cons_change_twh                                 -0.001164
# oil_consumption                                      0.023754
# oil_elec_per_capita                                  0.033911
# oil_energy_per_capita                                0.099648
# oil_production                                      -0.002113
# oil_prod_per_capita                                 -0.028261
# other_renewables_elec_per_capita                     0.411456
# other_renewables_share_elec                          1.000000
#
# [55 rows x 55 columns]

# %% [markdown]
# Para garantir que este pressuposto esta sendo atendido irei utilizar o teste estátistico de **Esfericidade de Bartlett**.
#
# * A hipótese nula é que as variáveis não são correlacionadas
#
# Para realizar esse teste em Python usaremos a função `calculate_bartlett_sphericity` do pacote `factor_analyzer`.
#
# **Atenção!** Este pacote não vem instalado por padrão! Para instalá-lo use o comando !pip install factor_analyzer.
#
# A função que desejamos está no pacote `factor_analyzer` dentro do módulo `factor_analyzer`

# %%
# Calculate bartlett sphericity and save p_values
p_value = calculate_bartlett_sphericity(df_scaled)[1]


# print test results 
print(F'p_value: {p_value}')
# Out:
# p_value: 0.0

# %% [markdown]
# Considerando um nível de significância de 5% e rejeitaremos a hipótese nula devido ao resultado do p_value ser menor do que 0.05, ou seja consideramos que há correlação entre todas as variáveis.

# %% [markdown]
# ### Pressuposto 2: Adequacidade da amostra

# %% [markdown]
# A medida de adequacidade da amostra de Kaiser-Meyer-Olkin (KMO) compara as magnitudes dos coeficientes de correlação observados com as magnitudes dos coeficientes de correlação parcial.
#
# A KMO é um valor que varia entre 0 e 1, e seu cálculo leva em consideração a inter-relação das variáveis presentes no conjunto de dados. Uma KMO próxima a 1 indica que as correlações entre as variáveis são grandes e, portanto, são adequadas para a análise fatorial. Por outro lado, uma KMO próxima a 0 sugere que as correlações são pequenas, o que torna a análise fatorial inadequada para o conjunto de dados.

# %%
# Calculate KMO and save results
kmo_value = calculate_kmo(df_scaled)[1]

# print results
print(f'KMO: {kmo_value}')
# Out:
# KMO: 0.6736536222925991
# c:\Users\aurelio\projetos\Portifolio-de-Projetos\.venv\Lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(

# %% [markdown]
# Como o valor de KMO é maior do que 0.5, podemos proceder com a análise fatorial, porém é importante observar que quanto maior esse valor, maior será a confiabilidade dos resultados obtidos.

# %% [markdown]
# ### Modeling

# %% [markdown]
# Agora que sabemos que a análise fatorial é adequada para ser usada em nosso caso, vamos realizar os seguintes passos:
#
# * Encontrar a quantidade ideal de fatores;
#
# * Rotacionar os fatores para facilitar suas interpretações.
#
#
# Para encontrar a quantidade de fatores, vamos olhar para os autovalores da matriz cargas fatoriais. Se o autovalor for maior que 1 então consideramos aquele fator como relevante.
#
# Para isso vamos usar a função `FactorAnalyzer` e o método `get_eigenvalues()` aplicado ao um objeto da classe FactorAnalyzer, após este calcular valores dos dados.
#
# O método `get_eigenvalues()` retorna dois objetos, sendo que o primeiro são os autovalores.

# %%
# training model
model = FactorAnalyzer(rotation = None)
model.fit(df_scaled)

# get eigenvalues for evaluate n factors
ev, v = model.get_eigenvalues()

# Showing result in lineplot
print(ev)
sns.lineplot(x=range(1, df_scaled.shape[1]+1), y=ev)
plt.title('Scree Plot')
plt.ylim(0,9)
plt.xlabel('Fatores')
plt.ylabel('Autovalores')
plt.grid()
plt.show()
# Out:
# c:\Users\aurelio\projetos\Portifolio-de-Projetos\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [1.29831956e+01 7.61748896e+00 4.76870798e+00 3.10916593e+00
#  2.71090493e+00 2.20643130e+00 1.88010439e+00 1.67273621e+00
#  1.41180884e+00 1.15797592e+00 1.15166666e+00 1.09715310e+00
#  1.06155253e+00 1.01913102e+00 1.00224963e+00 9.85016447e-01
#  9.06514990e-01 8.78487283e-01 8.17883492e-01 7.41240097e-01
#  7.09296551e-01 6.43417245e-01 5.49493624e-01 5.34202932e-01
#  4.49569921e-01 3.89973083e-01 3.52784274e-01 2.91897308e-01
#  2.88475372e-01 2.70618247e-01 1.73350786e-01 1.65373208e-01
#  1.46326670e-01 1.34414914e-01 1.02911011e-01 9.45091079e-02
#  8.70796348e-02 8.05118596e-02 7.19020530e-02 6.46543478e-02
#  5.14091130e-02 4.66489484e-02 2.98087046e-02 2.16019841e-02
#  1.63813885e-02 1.26365790e-02 1.05863630e-02 1.03100263e-02
#  8.15152218e-03 6.65352226e-03 2.74838799e-03 1.60560824e-03
#  6.76051114e-04 3.88504501e-04 2.15846247e-04]

# %% [markdown]
# Utilizando o gráfico Scree Plot podemos observar que é adequado a utilização até 13 fatores pois possuem um autovalor superior a 1.
#
# * Decidi então por utilizar 11 fatores

# %% [markdown]
# Podemos também calcular a variância explicada por cada fator e a variância explicada cumulativa.
#
# Para isso vamos usar o método `get_factor_variance()` aplicado ao nosso objetivo usado na realização da análise fatorial.

# %%
# criando um objeto para fazer análise fatorial com 4 fatores
model = FactorAnalyzer(n_factors=11, rotation=None)

# aplicando a análise fatorial aos dados
model.fit(df_scaled)

# criando nome para as colunas do DataFrame de cargas fatoriais
colunas = []
for i in range(11):
  colunas.append('Fator ' + str(i+1))

# criando DataFrame para auxiliar a visualização do resultado
variancia_fator = pd.DataFrame(model.get_factor_variance(),
                               index=['Variância','Variância Proporcional','Variância Acumulada'],
                               columns=colunas)

variancia_fator
# Out:
# c:\Users\aurelio\projetos\Portifolio-de-Projetos\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#                           Fator 1   Fator 2   Fator 3   Fator 4   Fator 5  \
# Variância               12.876739  7.439135  4.497151  2.969003  2.456664
# Variância Proporcional   0.234123  0.135257  0.081766  0.053982  0.044667
# Variância Acumulada      0.234123  0.369380  0.451146  0.505128  0.549794
#
#                          Fator 6   Fator 7   Fator 8   Fator 9  Fator 10  \
# Variância               2.020877  1.651009  1.437312  1.068755  0.930198
# Variância Proporcional  0.036743  0.030018  0.026133  0.019432  0.016913
# Variância Acumulada     0.586538  0.616556  0.642689  0.662121  0.679034
#
#                         Fator 11
# Variância               0.791425
# Variância Proporcional  0.014390
# Variância Acumulada     0.693423

# %% [markdown]
# Observando a variância acumulada, podemos afirmar que 11 fatores explicam aproximadamente 69% da variância total dos dados.

# %% [markdown]
# ### Comunalidades

# %% [markdown]
# Comunalidade representa a proporção da variância de uma variável original que é explicada pelos fatores latentes extraídos na análise fatorial.
#
# Quando realizamos a análise fatorial, cada variável original é expressa em termos dos fatores latentes obtidos. A comunalidade de uma variável é a soma dos quadrados dos coeficientes de regressão que relacionam a variável aos fatores. Em outras palavras, é a proporção da variância da variável que é compartilhada ou explicada pelos fatores.

# %%
pd.DataFrame(model.get_communalities(),
             index=df_scaled.columns,
             columns=['Comunalidades'])
# Out:
#                                   Comunalidades
# other_renewable_electricity            0.964362
# renewables_electricity                 0.942914
# solar_electricity                      0.852501
# wind_electricity                       0.988754
# energy_per_gdp                         0.281435
# energy_per_capita                      0.238713
# fossil_cons_change_pct                 0.198845
# fossil_share_energy                    0.927057
# fossil_cons_change_twh                 0.949529
# fossil_fuel_consumption                0.966027
# fossil_energy_per_capita               0.894769
# fossil_cons_per_capita                 0.697662
# fossil_share_elec                      0.933144
# gas_share_elec                         0.741493
# gas_cons_change_pct                    0.003697
# gas_share_energy                       0.556764
# gas_cons_change_twh                    0.723967
# gas_consumption                        0.965162
# gas_elec_per_capita                    0.563323
# gas_energy_per_capita                  0.758334
# gas_production                         0.901153
# gas_prod_per_capita                    0.443718
# hydro_share_elec                       0.908244
# hydro_cons_change_pct                  0.022462
# hydro_share_energy                     0.715285
# hydro_cons_change_twh                  0.430705
# hydro_consumption                      0.955303
# hydro_elec_per_capita                  0.861693
# hydro_energy_per_capita                0.934197
# low_carbon_share_elec                  1.020764
# low_carbon_electricity                 0.942689
# low_carbon_elec_per_capita             0.917661
# low_carbon_cons_change_pct             0.009943
# low_carbon_share_energy                0.846385
# low_carbon_cons_change_twh             1.041928
# low_carbon_consumption                 0.963544
# low_carbon_energy_per_capita           0.997176
# nuclear_share_elec                     0.849672
# nuclear_cons_change_pct                0.004147
# nuclear_share_energy                   0.952988
# nuclear_cons_change_twh                0.326718
# nuclear_consumption                    0.893835
# nuclear_elec_per_capita                0.932299
# nuclear_energy_per_capita              0.929255
# oil_share_elec                         0.567598
# oil_cons_change_pct                    0.222982
# oil_share_energy                       0.817970
# oil_cons_change_twh                    0.660386
# oil_consumption                        0.929366
# oil_elec_per_capita                    0.863818
# oil_energy_per_capita                  0.652679
# oil_production                         0.755464
# oil_prod_per_capita                    0.121344
# other_renewables_elec_per_capita       0.440079
# other_renewables_share_elec            0.156366

# %% [markdown]
# A comunalidade de uma variável pode variar de 0 a 1. Um valor de comunalidade próximo a 1 indica que a variável é bem representada pelos fatores e que a maior parte de sua variância é explicada pela estrutura comum dos dados. Por outro lado, uma comunalidade próxima a 0 indica que a variável não é bem representada pelos fatores e que a maioria de sua variância é específica da própria variável, não sendo compartilhada com os outros fatores.
#
# A comunalidade é útil para avaliar a qualidade da extração de fatores e a adequação da análise fatorial aos dados. Quanto maior a comunalidade média de todas as variáveis, mais confiável é a representação dos dados pelos fatores extraídos. Além disso, a comunalidade também é relevante para determinar a interpretabilidade dos fatores, pois variáveis com comunalidade baixa podem não ser tão úteis para explicar a estrutura subjacente dos dados.

# %% [markdown]
# ### Rotação

# %% [markdown]
# A rotação é um procedimento utilizado para facilitar a interpretação dos fatores extraídos. O objetivo da rotação é fazer com que os fatores sejam mais claramente identificáveis e interprestáveis.
#
# Após a extração dos fatores, os mesmos são geralmente expressos em termos de combinações lineares das variáveis originais. Essas combinações podem ser complexas e difíceis de interpretar diretamente. A rotação dos fatores busca simplificar a estrutura dos fatores, fazendo com que eles se tornem mais "nítidos" e "organizados", ao mesmo tempo em que mantêm a mesma quantidade de variância dos dados.

# %% [markdown]
# ### Utilizando uma função interativa para avaliar os diferentes tipos de rotação
# * **Infelizmente  não é possivel vizulizar o output da célula seguinte no github**

# %%
# Create a list with all rotation tips
rotation = ['varimax',
            'promax', 
            'oblimin',
            'oblimax',
            'quartimin',
            'quartimax',
            'equamax',
            None]

# create interactive plot to avalliate all rotation
@interact(changed = rotation)
def model(changed):
    model = pd.DataFrame(FactorAnalyzer(n_factors=11, rotation = changed)\
                                       .fit(df_scaled)\
                                       .loadings_,
                         index=df_scaled.columns,
                         columns=colunas)
    
    # create a dict to save values above 0.5
    fatores_variaveis = {}

    # filling in the dict
    for i in range(11):
      fatores_variaveis['Fator ' + str(i+1)] = model[abs(model.iloc[:,i]) > 0.5].iloc[:,i].index.tolist()    

    #Show plot and values dict
    #return sns.heatmap(model,vmin=-1, vmax=1, annot=False), fatores_variaveis
    return fatores_variaveis
# Out:
# interactive(children=(Dropdown(description='changed', options=('varimax', 'promax', 'oblimin', 'oblimax', 'qua…

# %% [markdown]
# * Selecionei a rotação varimax devido a explicabilidade dos fatores.
#
# Essa técnica de rotação visa maximizar a variância dos coeficientes de cada variável em um único fator, o que leva a fatores mais claros e mais facilmente interpretáveis.

# %%
# Training model
model = FactorAnalyzer(n_factors=11, rotation = 'varimax')
model.fit(df_scaled)

# save results in dataframe
cargas_fat = pd.DataFrame(model.loadings_,
                          index=df_scaled.columns,
                          columns=colunas)

fatores_variaveis = {}
# preenchendo o dicionário
for i in range(11):
  fatores_variaveis['Fator ' + str(i+1)] = cargas_fat[abs(cargas_fat.iloc[:,i]) > 0.5].iloc[:,i].index.tolist()  

fatores_variaveis
# Out:
# c:\Users\aurelio\projetos\Portifolio-de-Projetos\.venv\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# {'Fator 1': ['other_renewable_electricity',
#   'renewables_electricity',
#   'wind_electricity',
#   'fossil_cons_change_twh',
#   'fossil_fuel_consumption',
#   'gas_cons_change_twh',
#   'gas_consumption',
#   'gas_production',
#   'hydro_consumption',
#   'low_carbon_electricity',
#   'low_carbon_cons_change_twh',
#   'low_carbon_consumption',
#   'nuclear_consumption',
#   'oil_consumption',
#   'oil_production'],
#  'Fator 2': ['hydro_share_energy',
#   'hydro_elec_per_capita',
#   'hydro_energy_per_capita',
#   'low_carbon_elec_per_capita',
#   'low_carbon_share_energy',
#   'low_carbon_energy_per_capita',
#   'other_renewables_elec_per_capita'],
#  'Fator 3': ['nuclear_share_elec',
#   'nuclear_share_energy',
#   'nuclear_elec_per_capita',
#   'nuclear_energy_per_capita'],
#  'Fator 4': ['fossil_energy_per_capita',
#   'fossil_cons_per_capita',
#   'gas_share_energy',
#   'gas_elec_per_capita',
#   'gas_energy_per_capita',
#   'gas_prod_per_capita',
#   'oil_energy_per_capita'],
#  'Fator 5': ['fossil_share_energy', 'oil_share_energy'],
#  'Fator 6': ['other_renewable_electricity',
#   'solar_electricity',
#   'wind_electricity'],
#  'Fator 7': ['hydro_share_elec', 'low_carbon_share_elec'],
#  'Fator 8': ['fossil_cons_per_capita',
#   'oil_share_elec',
#   'oil_elec_per_capita'],
#  'Fator 9': ['fossil_share_elec', 'gas_share_elec'],
#  'Fator 10': ['fossil_cons_change_twh', 'oil_cons_change_twh'],
#  'Fator 11': ['low_carbon_cons_change_twh']}

# %% [markdown]
# ### Output

# %% [markdown]
# Como a quantidade de variáveis é muito grande, transformei o output das variáveis explicativas da AFE em um dataframe para uma melhor visualização.

# %%
pd.DataFrame.from_dict([fatores_variaveis.get(f"Fator 2")]).T\
  .rename({0:"Fator 2"},axis = 1)
# Out:
#                             Fator 2
# 0                hydro_share_energy
# 1             hydro_elec_per_capita
# 2           hydro_energy_per_capita
# 3        low_carbon_elec_per_capita
# 4           low_carbon_share_energy
# 5      low_carbon_energy_per_capita
# 6  other_renewables_elec_per_capita

# %% [markdown]
# Como podemos observar, o fator 2, por exemplo, poderia ser renomeado para "Geração Sustentável de Energia", assim simplificando o conjunto de dados e trazendo mais clareza e interpretabilidade para a análise. Ao atribuir um nome significativo aos fatores, conseguimos resumir as variáveis associadas a cada fator em uma única categoria temática, tornando mais fácil entender a essência do fator e sua relação com as variáveis originais. Essa abordagem é vantajosa para a comunicação dos resultados da análise fatorial, pois facilita a discussão e a compreensão dos padrões subjacentes nos dados relacionados à geração sustentável de energia. Além disso, ao nomear os fatores de forma informativa, estamos enriquecendo a interpretação da análise e tornando-a mais acessível para outros pesquisadores ou partes interessadas envolvidas no estudo

# %% [markdown]
# Para melhor análise dos fatores criei uma função interativa para percorrer cada Fator gerado pelo modelo

# %% [markdown]
# **Função interativa, output da célula não vizivel no Github**

# %%
@interact(fator = list(np.arange(1,12)))
def view(fator):
    return pd.DataFrame.from_dict([fatores_variaveis.get(f"Fator {fator}")]).T\
             .rename({0:f"Fator {fator}"},axis = 1)
# Out:
# interactive(children=(Dropdown(description='fator', options=(np.int64(1), np.int64(2), np.int64(3), np.int64(4…

# %% [markdown]
# ### Ranqueamento

# %% [markdown]
# Embora não se aplique a este estudo em particular, é possível ranquear o conjunto de dados se tivermos algum rótulo ou ID que permita melhor compreensão dos dados. O ranqueamento pode ser útil para ordenar as observações de acordo com algum critério específico, o que pode facilitar a análise ou a interpretação dos resultados em algumas situações.

# %%
# Calculate racking results
weights = model.loadings_
matriz_df = np.asmatrix(df_scaled)
matriz_peso = np.asmatrix(weights)
mult_matriz = np.round(np.dot(matriz_df, matriz_peso),4)
variancia = model.get_factor_variance()[1]
resultado = np.round(np.dot(mult_matriz, variancia), 4)

resultado
# Out:
# array([-1.1365, -1.1365, -1.1365, ..., -0.6479, -0.631 , -0.6231],
#       shape=(17432,))

# %%
# Create a copy dataframe with column factor rank
top = df.assign(Rancking_fator = resultado.tolist())\
               .sort_values(by = 'Rancking_fator', ascending = False)

# %%
top.head()
# Out:
#        other_renewable_electricity  renewables_electricity  solar_electricity  \
# 17022                      663.847                6712.063            572.908
# 17023                      682.877                7065.089            704.024
# 17021                      622.176                6276.014            443.315
# 17020                      592.389                5900.412            329.564
# 17014                      406.001                4168.712             30.518
#
#        wind_electricity  energy_per_gdp  energy_per_capita  \
# 17022          1266.086           0.000          20975.203
# 17023          1416.947           0.000          21027.415
# 17021          1135.069           0.000          20624.761
# 17020           958.942           1.429          20490.955
# 17014           346.471           1.588          20204.963
#
#        fossil_cons_change_pct  fossil_share_energy  fossil_cons_change_twh  \
# 17022                   2.486               84.846                3294.567
# 17023                   0.703               84.320                 954.370
# 17021                   1.382               85.123                1806.839
# 17020                   0.918               85.459                1189.562
# 17014                   4.714               86.574                5477.970
#
#        fossil_fuel_consumption  ...  oil_share_energy  oil_cons_change_twh  \
# 17022               135807.237  ...            33.225              613.605
# 17023               136761.607  ...            33.059              438.800
# 17021               132512.670  ...            33.768              647.364
# 17020               130705.831  ...            33.947             1028.180
# 17014               121691.136  ...            34.211             1433.631
#
#        oil_consumption  oil_elec_per_capita  oil_energy_per_capita  \
# 17022        53181.125              149.968               6969.007
# 17023        53619.925              141.222               6951.468
# 17021        52567.520              148.510               6964.560
# 17020        51920.156              161.120               6956.056
# 17014        48087.136              151.770               6912.225
#
#        oil_production  oil_prod_per_capita  other_renewables_elec_per_capita  \
# 17022       52244.640             6846.287                            86.992
# 17023       52069.986             6750.529                            88.531
# 17021       51013.260             6758.640                            82.431
# 17020       50843.437             6811.802                            79.366
# 17014       46251.552             6648.372                            58.360
#
#        other_renewables_share_elec  Rancking_fator
# 17022                        2.597         90.0116
# 17023                        2.637         87.5800
# 17021                        2.532         79.2038
# 17020                        2.476         76.2831
# 17014                        1.954         73.6692
#
# [5 rows x 56 columns]
